# %% [markdown]
# # 1- Data Acquisition

# %% [markdown]
# I import the dataset for using it in my analaysis which is world Happiness report for 2015

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import collections
## importing of needed libraries

# %%
Happiness_file= pd.read_csv('2015.csv')
Happiness_file
## reading file of data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  Standard Error  Economy   Family  \
# 0              7.587         0.03411  1.39651  1.34951
# 1              7.561         0.04884  1.30232  1.40223
# ...

# %%
Happiness_file.shape
## knowing the number of rows and columns in data
# Out:
# (158, 12)

# %%
Happiness_file.describe()
## descrcribing of data in sum details like getting max , min ,mean , count and others
# Out:
#        Happiness Rank  Happiness_Score  Standard Error     Economy  \
# count      158.000000       158.000000      158.000000  158.000000
# mean        79.493671         5.375734        0.047885    0.846137
# std         45.754363         1.145010        0.017146    0.403121
# min          1.000000         2.839000        0.018480    0.000000
# 25%         40.250000         4.526000        0.037268    0.545808
# 50%         79.500000         5.232500        0.043940    0.910245
# 75%        118.750000         6.243750        0.052300    1.158448
# max        158.000000         7.587000        0.136930    1.690420
#
#            Family  Health (Life Expectancy)     Freedom  \
# count  158.000000                158.000000  158.000000
# mean     0.991046                  0.630259    0.428615
# std      0.272369                  0.247078    0.150693
# min      0.000000                  0.000000    0.000000
# 25%      0.856823                  0.439185    0.328330
# ...

# %%
Happiness_world=pd.read_csv("2015.csv",
                            usecols=['Happiness_Score','Economy'])
Happiness_world[10:]
## import 2015 world happiness dataset and read only needed columns Happiness _Score and Economy 
## view  10 rows of two columns first 5 rows and last 5 rows
##Happiness_world including the dataset but with two column only Happiness_Score and Economy
# Out:
#      Happiness_Score  Economy
# 10             7.278  1.22857
# 11             7.226  0.95578
# 12             7.200  1.33723
# 13             7.187  1.02054
# 14             7.119  1.39451
# ..               ...      ...
# 153            3.465  0.22208
# 154            3.340  0.28665
# 155            3.006  0.66320
# 156            2.905  0.01530
# 157            2.839  0.20868
#
# [148 rows x 2 columns]

# %% [markdown]
# # 2-Data Preparation

# %% [markdown]
# i prepare data before analysing i will remove null values

# %%
print(Happiness_world.Economy.value_counts())
print(Happiness_world.Happiness_Score.value_counts())
## check for null values
# Out:
# 1.39651    1
# 0.39753    1
# 1.15406    1
# 1.02564    1
# 1.12094    1
#           ..
# 1.12254    1
# 1.18498    1
# 1.14723    1
# 0.59325    1
# 0.20868    1
# Name: Economy, Length: 158, dtype: int64
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness_Score, Length: 157, dtype: int64

# %%
Values=Happiness_world.isnull()
Values
## check if there any missing values
## there is no missing values in which rows which i select
# Out:
#      Happiness_Score  Economy
# 0              False    False
# 1              False    False
# 2              False    False
# 3              False    False
# 4              False    False
# ..               ...      ...
# 153            False    False
# 154            False    False
# 155            False    False
# 156            False    False
# 157            False    False
#
# [158 rows x 2 columns]

# %% [markdown]
# # 3-Data Visualization and Analysis

# %% [markdown]
# In this stage i will create pivot and data visualization

# %%
result_pivot=Happiness_world.pivot_table(index=['Economy','Happiness_Score'],aggfunc=np.max)
result_pivot
## making pivot table on the realtion netween two columns Happiness_Score and Economy
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
result_pivot2=Happiness_world.pivot_table(index=['Happiness_Score'],aggfunc=np.max)
result_pivot2
## here making pivot table on Happiness_Score and show that economy has relation with Happiness_Score
# Out:
#                  Economy
# Happiness_Score
# 2.839            0.20868
# 2.905            0.01530
# 3.006            0.66320
# 3.340            0.28665
# 3.465            0.22208
# ...                  ...
# 7.427            1.32629
# 7.522            1.45900
# 7.527            1.32548
# 7.561            1.30232
# 7.587            1.39651
#
# [157 rows x 1 columns]

# %% [markdown]
# # Here checking of the relation between Happiness_Score column and Economy by plotting the realtion

# %%
import matplotlib.pyplot as plt
plt.scatter(x=Happiness_world1['Economy'],y=Happiness_world1['Happiness_Score'])
## visualization od data

# %%
Happiness_world[['Happiness_Score','Economy']].plot.line(x='Happiness_Score', y='Economy', 
                                                           figsize=(30,10), grid=True)
# Out:
# <AxesSubplot:xlabel='Happiness_Score'>

# %%
scipy.stats.pearsonr(Happiness_world['Happiness_Score'], 
                     Happiness_world['Economy'])
## the correlation is 0.7 is a strong relation between Happiness score and economy 
## pvalue is getting to 0
# Out:
# PearsonRResult(statistic=0.7809655268660215, pvalue=1.050538413195872e-33)

# %% [markdown]
# the correlation is 0.7 is a strong relation between Happiness score and economy
#  pvalue is getting to 0
